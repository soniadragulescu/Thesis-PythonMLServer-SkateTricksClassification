# %%
#necessary libraries
from keras.preprocessing import image
import numpy as np
import pandas as pd
from tqdm import tqdm
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.layers import Dense,  Dropout
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint

#Remember, we created a .csv file that contains the names of each frame and their corresponding tag? Let’s read it as well:
#This is how the first five rows look like. We have the corresponding class or tag for each frame.

train = pd.read_csv('datas/train_skate.csv')
train.head()
# Out:
#                      image class
# 0  Fail_001.mp4_frame0.jpg  Fail
# 1  Fail_001.mp4_frame1.jpg  Fail
# 2  Fail_001.mp4_frame2.jpg  Fail
# 3  Fail_001.mp4_frame3.jpg  Fail
# 4  Fail_002.mp4_frame0.jpg  Fail

# %%
#using this .csv file, we will read the frames that we extracted earlier and then store those frames as a NumPy array:
# creating an empty list
train_image = []

# for loop to read and store frames
for i in tqdm(range(train.shape[0])):
    # loading the image and keeping the target size as (224,224,3)
    img = image.load_img('datas/train_frames/' + train['image'][i], target_size=(224, 224, 3))
    # converting it to array
    img = image.img_to_array(img)
    # normalizing the pixel value
    img = img / 255
    # appending the image to the train_image list
    train_image.append(img)

# converting the list to numpy array
X = np.asarray(train_image)
# shape of the array
X.shape
# Out:
# 100%|██████████| 500/500 [00:03<00:00, 151.96it/s]
# (500, 224, 224, 3)

# %%
# Next, we will create the validation set.

#To create the validation set,
# we need to make sure that the distribution of each class is similar in both training and validation sets.
# We can use the stratify parameter to do that:

# separating the target
y = train['class']
print(y)

# creating the training and validation set
#Here, stratify = y (which is the class or tags of each frame)
# keeps the similar distribution of classes in both the training as well as the validation set.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2, stratify = y)


# creating dummies of target variable for train and validation set
#Remember – there are 3 categories in which a video can be classified.
# So, we will have to create 3 different columns in the target,
# one for each category.

# We will use the get_dummies() function for that:
y_train = pd.get_dummies(y_train)
y_test = pd.get_dummies(y_test)
# Out:
# 0       Fail
# 1       Fail
# 2       Fail
# 3       Fail
# 4       Fail
#        ...
# 495    Slide
# 496    Slide
# 497    Slide
# 498    Slide
# 499    Slide
# Name: class, Length: 500, dtype: object

# %%
#Defining the architecture of the video classification model

#Since we do not have a very large dataset,
# creating a model from scratch might not work well.
# So, we will use a pre-trained model and take its learnings to solve our problem.

#For this particular dataset,
# we will be using the VGG-16 pre-trained model.
# Let’s create a base model of the pre-trained model:

# creating the base model of pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False)

# %%
#This model was trained on a dataset that has 1,000 classes.
# We will fine tune this model as per our requirement.
# include_top = False will remove the last layer of this model so that we can tune it as per our need.

#Now, we will extract features from this pre-trained model for our training and validation images:

# extracting features for training frames
X_train = base_model.predict(X_train)
X_train.shape
# Out:
# (400, 7, 7, 512)

# %%
#We have 400 images in the training set
# and the shape has been changed to (7, 7, 512)
# since we have passed these images through the VGG16 architecture.
# Similarly, we will extract features for validation frames:

# extracting features for validation frames
X_test = base_model.predict(X_test)
X_test.shape
# Out:
# (100, 7, 7, 512)

# %%
#There are 100 images in the validation set
# and the shape of these images has also changed to (7, 7, 512).
# We will use a fully connected network now to fine-tune the model.
# This fully connected network takes input in single dimension.
# So, we will reshape the images into a single dimension:

# reshaping the training as well as validation frames in single dimension
X_train = X_train.reshape(400, 7*7*512)
X_test = X_test.reshape(100, 7*7*512)

# %%
#It is always advisable to normalize the pixel values, i.e.,
# keep the pixel values between 0 and 1.
# This helps the model to converge faster.

# normalizing the pixel values
max = X_train.max()
X_train = X_train/max
X_test = X_test/max

#Next, we will create the architecture of the model.
# We have to define the input shape for that.
# So, let’s check the shape of our images:

# shape of images
X_train.shape
# Out:
# (400, 25088)

# %%
#The input shape will be 25088.
# Let’s now create the architecture.

#We have multiple fully connected dense layers.
# I have added dropout layers as well so that the model will not overfit.
# The number of neurons in the final layer is equal to
# the number of classes that we have and hence the number of neurons here is 3.

#defining the model architecture
model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(25088,)))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

# %%
#Training the video classification model

#We will now train our model using the training frames and validate the model using validation frames.
# We will save the weights of the model so that we will not have to retrain the model again and again.
#So, let’s define a function to save the weights of the model:

mcp_save = ModelCheckpoint('weights_skate.hdf5', save_best_only=True, monitor='val_loss', mode='min')

# %%
#We will decide the optimum model based on the validation loss.
# Note that the weights will be saved as weights_skate.hdf5.
# Before training the model, we have to compile it:

# compiling the model
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
#We are using the categorical_crossentropy as the loss function and the optimizer is Adam.
# Let’s train the model:

# training the model
model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), callbacks=[mcp_save], batch_size=128)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 207ms/step - loss: 1.1038 - accuracy: 0.3689 - val_loss: 1.0345 - val_accuracy: 0.4200
# Epoch 2/200
# 4/4 [==============================] - 1s 144ms/step - loss: 1.1835 - accuracy: 0.4524 - val_loss: 1.0146 - val_accuracy: 0.5900
# Epoch 3/200
# 4/4 [==============================] - 1s 135ms/step - loss: 1.1693 - accuracy: 0.4451 - val_loss: 0.9789 - val_accuracy: 0.5100
# Epoch 4/200
# 4/4 [==============================] - 1s 153ms/step - loss: 1.0969 - accuracy: 0.4659 - val_loss: 0.9395 - val_accuracy: 0.5500
# Epoch 5/200
# 4/4 [==============================] - 0s 129ms/step - loss: 1.0474 - accuracy: 0.4802 - val_loss: 0.9216 - val_accuracy: 0.6400
# Epoch 6/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.9685 - accuracy: 0.5601 - val_loss: 0.8993 - val_accuracy: 0.6400
# Epoch 7/200
# 4/4 [==============================] - 0s 129ms/step - loss: 0.8848 - accuracy: 0.6025 - val_loss: 0.8465 - val_accuracy: 0.6500
# Epoch 8/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.8727 - accuracy: 0.6122 - val_loss: 0.7611 - val_accuracy: 0.6900
# Epoch 9/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.7701 - accuracy: 0.6843 - val_loss: 0.7239 - val_accuracy: 0.6600
# Epoch 10/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.6733 - accuracy: 0.7226 - val_loss: 0.7289 - val_accuracy: 0.6700
# Epoch 11/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.6974 - accuracy: 0.7221 - val_loss: 0.6689 - val_accuracy: 0.7300
# Epoch 12/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.5964 - accuracy: 0.7494 - val_loss: 0.7217 - val_accuracy: 0.7300
# Epoch 13/200
# 4/4 [==============================] - 1s 149ms/step - loss: 0.6386 - accuracy: 0.7440 - val_loss: 0.6070 - val_accuracy: 0.7600
# Epoch 14/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.5198 - accuracy: 0.7774 - val_loss: 0.5679 - val_accuracy: 0.8000
# Epoch 15/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.4525 - accuracy: 0.8066 - val_loss: 0.5634 - val_accuracy: 0.8300
# Epoch 16/200
# 4/4 [==============================] - 1s 131ms/step - loss: 0.3557 - accuracy: 0.8749 - val_loss: 0.4827 - val_accuracy: 0.8700
# Epoch 17/200
# 4/4 [==============================] - 1s 148ms/step - loss: 0.3053 - accuracy: 0.9101 - val_loss: 0.4927 - val_accuracy: 0.8400
# Epoch 18/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.2604 - accuracy: 0.9163 - val_loss: 0.4512 - val_accuracy: 0.8900
# Epoch 19/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.2206 - accuracy: 0.9408 - val_loss: 0.5093 - val_accuracy: 0.8600
# Epoch 20/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.2100 - accuracy: 0.9337 - val_loss: 0.4587 - val_accuracy: 0.8700
# Epoch 21/200
# 4/4 [==============================] - 1s 131ms/step - loss: 0.1644 - accuracy: 0.9652 - val_loss: 0.3848 - val_accuracy: 0.9100
# Epoch 22/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.1312 - accuracy: 0.9524 - val_loss: 0.4866 - val_accuracy: 0.8700
# Epoch 23/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.1217 - accuracy: 0.9577 - val_loss: 0.4838 - val_accuracy: 0.8600
# Epoch 24/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0660 - accuracy: 0.9877 - val_loss: 0.4048 - val_accuracy: 0.9100
# Epoch 25/200
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0626 - accuracy: 0.9878 - val_loss: 0.4376 - val_accuracy: 0.9100
# Epoch 26/200
# 4/4 [==============================] - 1s 167ms/step - loss: 0.0653 - accuracy: 0.9713 - val_loss: 0.4525 - val_accuracy: 0.9000
# Epoch 27/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.0377 - accuracy: 0.9877 - val_loss: 0.3929 - val_accuracy: 0.9300
# Epoch 28/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0361 - accuracy: 0.9885 - val_loss: 0.4467 - val_accuracy: 0.9000
# Epoch 29/200
# 4/4 [==============================] - 1s 160ms/step - loss: 0.0295 - accuracy: 0.9908 - val_loss: 0.5963 - val_accuracy: 0.8500
# Epoch 30/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0243 - accuracy: 0.9954 - val_loss: 0.5226 - val_accuracy: 0.8600
# Epoch 31/200
# 4/4 [==============================] - 1s 152ms/step - loss: 0.0177 - accuracy: 0.9975 - val_loss: 0.4667 - val_accuracy: 0.9100
# Epoch 32/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0120 - accuracy: 0.9985 - val_loss: 0.6170 - val_accuracy: 0.8800
# Epoch 33/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0233 - accuracy: 0.9946 - val_loss: 0.5901 - val_accuracy: 0.9000
# Epoch 34/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.9100
# Epoch 35/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0142 - accuracy: 0.9938 - val_loss: 0.4817 - val_accuracy: 0.9100
# Epoch 36/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0123 - accuracy: 0.9946 - val_loss: 0.5580 - val_accuracy: 0.8900
# Epoch 37/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0099 - accuracy: 0.9985 - val_loss: 0.5513 - val_accuracy: 0.9000
# Epoch 38/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.9100
# Epoch 39/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.0072 - accuracy: 0.9960 - val_loss: 0.4764 - val_accuracy: 0.9300
# Epoch 40/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.6207 - val_accuracy: 0.8800
# Epoch 41/200
# 4/4 [==============================] - 1s 159ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.7668 - val_accuracy: 0.8700
# Epoch 42/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.7807 - val_accuracy: 0.8700
# Epoch 43/200
# 4/4 [==============================] - 1s 166ms/step - loss: 0.0081 - accuracy: 0.9990 - val_loss: 0.5244 - val_accuracy: 0.9200
# Epoch 44/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 0.6253 - val_accuracy: 0.9100
# Epoch 45/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0505 - accuracy: 0.9861 - val_loss: 0.8028 - val_accuracy: 0.8200
# Epoch 46/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0249 - accuracy: 0.9924 - val_loss: 0.7292 - val_accuracy: 0.8700
# Epoch 47/200
# 4/4 [==============================] - 1s 155ms/step - loss: 0.0126 - accuracy: 0.9946 - val_loss: 0.4508 - val_accuracy: 0.9400
# Epoch 48/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0245 - accuracy: 0.9908 - val_loss: 0.6196 - val_accuracy: 0.9100
# Epoch 49/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.6386 - val_accuracy: 0.9100
# Epoch 50/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.7723 - val_accuracy: 0.8700
# Epoch 51/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.8640 - val_accuracy: 0.8600
# Epoch 52/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.0135 - accuracy: 0.9946 - val_loss: 0.5769 - val_accuracy: 0.9000
# Epoch 53/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.4817 - val_accuracy: 0.9300
# Epoch 54/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0192 - accuracy: 0.9961 - val_loss: 0.5667 - val_accuracy: 0.9300
# Epoch 55/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.6801 - val_accuracy: 0.9100
# Epoch 56/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0055 - accuracy: 0.9961 - val_loss: 0.7507 - val_accuracy: 0.9000
# Epoch 57/200
# 4/4 [==============================] - 1s 193ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 0.6721 - val_accuracy: 0.9100
# Epoch 58/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6409 - val_accuracy: 0.9200
# Epoch 59/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6234 - val_accuracy: 0.9100
# Epoch 60/200
# 4/4 [==============================] - 1s 154ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6613 - val_accuracy: 0.9000
# Epoch 61/200
# 4/4 [==============================] - 1s 165ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.7163 - val_accuracy: 0.9000
# Epoch 62/200
# 4/4 [==============================] - 1s 145ms/step - loss: 0.0039 - accuracy: 0.9961 - val_loss: 0.7550 - val_accuracy: 0.9000
# Epoch 63/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.7496 - val_accuracy: 0.9000
# Epoch 64/200
# 4/4 [==============================] - 1s 141ms/step - loss: 7.5998e-04 - accuracy: 1.0000 - val_loss: 0.7492 - val_accuracy: 0.9000
# Epoch 65/200
#  - 1s 142ms/step - loss: 5.3768e-04 - accuracy: 1.0000 - val_loss: 0.7483 - val_accuracy: 0.9000
# Epoch 66/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.7453 - val_accuracy: 0.9000
# Epoch 67/200
# 4/4 [==============================] - 1s 140ms/step - loss: 4.5335e-04 - accuracy: 1.0000 - val_loss: 0.7465 - val_accuracy: 0.9100
# Epoch 68/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.7388 - val_accuracy: 0.9100
# Epoch 69/200
# 4/4 [==============================] - 1s 139ms/step - loss: 6.8060e-04 - accuracy: 1.0000 - val_loss: 0.7269 - val_accuracy: 0.9200
# Epoch 70/200
# 4/4 [==============================] - 1s 134ms/step - loss: 8.6580e-04 - accuracy: 1.0000 - val_loss: 0.7183 - val_accuracy: 0.9200
# Epoch 71/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.7365 - val_accuracy: 0.9200
# Epoch 72/200
# 4/4 [==============================] - 1s 141ms/step - loss: 2.7412e-04 - accuracy: 1.0000 - val_loss: 0.7469 - val_accuracy: 0.9100
# Epoch 73/200
# 4/4 [==============================] - 1s 132ms/step - loss: 5.7039e-04 - accuracy: 1.0000 - val_loss: 0.7550 - val_accuracy: 0.9100
# Epoch 74/200
# 4/4 [==============================] - 1s 163ms/step - loss: 2.9910e-04 - accuracy: 1.0000 - val_loss: 0.7610 - val_accuracy: 0.9100
# Epoch 75/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0028 - accuracy: 0.9977 - val_loss: 0.7917 - val_accuracy: 0.9000
# Epoch 76/200
# 4/4 [==============================] - 1s 138ms/step - loss: 5.3071e-04 - accuracy: 1.0000 - val_loss: 0.8203 - val_accuracy: 0.9000
# Epoch 77/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8288 - val_accuracy: 0.9000
# Epoch 78/200
# 4/4 [==============================] - 1s 139ms/step - loss: 3.2310e-04 - accuracy: 1.0000 - val_loss: 0.8299 - val_accuracy: 0.9000
# Epoch 79/200
# 4/4 [==============================] - 1s 137ms/step - loss: 5.6311e-04 - accuracy: 1.0000 - val_loss: 0.8317 - val_accuracy: 0.9000
# Epoch 80/200
# 4/4 [==============================] - 1s 140ms/step - loss: 5.9395e-04 - accuracy: 1.0000 - val_loss: 0.8289 - val_accuracy: 0.9000
# Epoch 81/200
# 4/4 [==============================] - 1s 135ms/step - loss: 4.0983e-04 - accuracy: 1.0000 - val_loss: 0.8252 - val_accuracy: 0.9000
# Epoch 82/200
# 4/4 [==============================] - 1s 137ms/step - loss: 8.8954e-04 - accuracy: 1.0000 - val_loss: 0.8211 - val_accuracy: 0.9000
# Epoch 83/200
# 4/4 [==============================] - 1s 152ms/step - loss: 4.8002e-04 - accuracy: 1.0000 - val_loss: 0.8138 - val_accuracy: 0.9000
# Epoch 84/200
# 4/4 [==============================] - 1s 152ms/step - loss: 4.0113e-04 - accuracy: 1.0000 - val_loss: 0.8126 - val_accuracy: 0.9000
# Epoch 85/200
# 4/4 [==============================] - 1s 139ms/step - loss: 2.8675e-04 - accuracy: 1.0000 - val_loss: 0.8136 - val_accuracy: 0.9000
# Epoch 86/200
# 4/4 [==============================] - 1s 138ms/step - loss: 8.0296e-04 - accuracy: 1.0000 - val_loss: 0.8212 - val_accuracy: 0.9000
# Epoch 87/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0045 - accuracy: 0.9977 - val_loss: 0.7463 - val_accuracy: 0.9200
# Epoch 88/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7523 - val_accuracy: 0.9100
# Epoch 89/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0084 - accuracy: 0.9985 - val_loss: 0.6967 - val_accuracy: 0.9100
# Epoch 90/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.7278 - val_accuracy: 0.9000
# Epoch 91/200
# 4/4 [==============================] - 1s 137ms/step - loss: 5.2092e-04 - accuracy: 1.0000 - val_loss: 0.8232 - val_accuracy: 0.8900
# Epoch 92/200
# 4/4 [==============================] - 1s 140ms/step - loss: 5.3908e-04 - accuracy: 1.0000 - val_loss: 0.8974 - val_accuracy: 0.8900
# Epoch 93/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0048 - accuracy: 0.9961 - val_loss: 0.7786 - val_accuracy: 0.9000
# Epoch 94/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0047 - accuracy: 0.9961 - val_loss: 0.6749 - val_accuracy: 0.9100
# Epoch 95/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0181 - accuracy: 0.9961 - val_loss: 0.6226 - val_accuracy: 0.9200
# Epoch 96/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.6993 - val_accuracy: 0.9100
# Epoch 97/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.8323 - val_accuracy: 0.8800
# Epoch 98/200
# 4/4 [==============================] - 1s 147ms/step - loss: 6.5310e-04 - accuracy: 1.0000 - val_loss: 1.0810 - val_accuracy: 0.8300
# Epoch 99/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0270 - accuracy: 0.9961 - val_loss: 0.7254 - val_accuracy: 0.9000
# Epoch 100/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0069 - accuracy: 0.9961 - val_loss: 0.7652 - val_accuracy: 0.9100
# Epoch 101/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0133 - accuracy: 0.9954 - val_loss: 0.7574 - val_accuracy: 0.8900
# Epoch 102/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0251 - val_accuracy: 0.8400
# Epoch 103/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.9270 - val_accuracy: 0.8600
# Epoch 104/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 0.5665 - val_accuracy: 0.9300
# Epoch 105/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0050 - accuracy: 0.9962 - val_loss: 0.5086 - val_accuracy: 0.9200
# Epoch 106/200
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0362 - accuracy: 0.9961 - val_loss: 0.6350 - val_accuracy: 0.9100
# Epoch 107/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0065 - accuracy: 0.9931 - val_loss: 0.7394 - val_accuracy: 0.8900
# Epoch 108/200
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0128 - accuracy: 0.9946 - val_loss: 0.5427 - val_accuracy: 0.9400
# Epoch 109/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0189 - accuracy: 0.9961 - val_loss: 0.8671 - val_accuracy: 0.9000
# Epoch 110/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0398 - accuracy: 0.9931 - val_loss: 0.6060 - val_accuracy: 0.9200
# Epoch 111/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.6589 - val_accuracy: 0.8800
# Epoch 112/200
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0239 - accuracy: 0.9931 - val_loss: 0.8000 - val_accuracy: 0.9000
# Epoch 113/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0025 - accuracy: 0.9985 - val_loss: 1.1614 - val_accuracy: 0.8600
# Epoch 114/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0520 - accuracy: 0.9884 - val_loss: 0.8567 - val_accuracy: 0.8900
# Epoch 115/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.9849 - val_accuracy: 0.8600
# Epoch 116/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0183 - accuracy: 0.9977 - val_loss: 0.7469 - val_accuracy: 0.8900
# Epoch 117/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6259 - val_accuracy: 0.9000
# Epoch 118/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0411 - accuracy: 0.9854 - val_loss: 0.9709 - val_accuracy: 0.8300
# Epoch 119/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0364 - accuracy: 0.9861 - val_loss: 0.6691 - val_accuracy: 0.8600
# Epoch 120/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.6014 - val_accuracy: 0.9200
# Epoch 121/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0162 - accuracy: 0.9961 - val_loss: 0.6673 - val_accuracy: 0.8900
# Epoch 122/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0079 - accuracy: 0.9962 - val_loss: 1.0654 - val_accuracy: 0.8400
# Epoch 123/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0449 - accuracy: 0.9931 - val_loss: 0.7260 - val_accuracy: 0.9100
# Epoch 124/200
# 4/4 [==============================] - 1s 165ms/step - loss: 0.0274 - accuracy: 0.9938 - val_loss: 0.5034 - val_accuracy: 0.9100
# Epoch 125/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0189 - accuracy: 0.9923 - val_loss: 0.8427 - val_accuracy: 0.8700
# Epoch 126/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0239 - accuracy: 0.9937 - val_loss: 0.5089 - val_accuracy: 0.8900
# Epoch 127/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0769 - accuracy: 0.9817 - val_loss: 0.7205 - val_accuracy: 0.8700
# Epoch 128/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0509 - accuracy: 0.9855 - val_loss: 0.7528 - val_accuracy: 0.8600
# Epoch 129/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 0.5022 - val_accuracy: 0.9000
# Epoch 130/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.6623 - val_accuracy: 0.8800
# Epoch 131/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0166 - accuracy: 0.9938 - val_loss: 0.6537 - val_accuracy: 0.8700
# Epoch 132/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0142 - accuracy: 0.9960 - val_loss: 0.7114 - val_accuracy: 0.8700
# Epoch 133/200
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0200 - accuracy: 0.9977 - val_loss: 0.9365 - val_accuracy: 0.8500
# Epoch 134/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 0.5076 - val_accuracy: 0.9300
# Epoch 135/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0395 - accuracy: 0.9829 - val_loss: 0.7544 - val_accuracy: 0.8500
# Epoch 136/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.1018 - accuracy: 0.9716 - val_loss: 0.5871 - val_accuracy: 0.8700
# Epoch 137/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.1091 - accuracy: 0.9646 - val_loss: 0.9228 - val_accuracy: 0.8800
# Epoch 138/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.1693 - accuracy: 0.9662 - val_loss: 1.0662 - val_accuracy: 0.8200
# Epoch 139/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.1061 - accuracy: 0.9692 - val_loss: 0.6205 - val_accuracy: 0.9200
# Epoch 140/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0463 - accuracy: 0.9878 - val_loss: 0.6516 - val_accuracy: 0.9100
# Epoch 141/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.8916 - val_accuracy: 0.8700
# Epoch 142/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0317 - accuracy: 0.9892 - val_loss: 0.6438 - val_accuracy: 0.9200
# Epoch 143/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0179 - accuracy: 0.9954 - val_loss: 0.5499 - val_accuracy: 0.9300
# Epoch 144/200
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0078 - accuracy: 0.9946 - val_loss: 0.6042 - val_accuracy: 0.9100
# Epoch 145/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0084 - accuracy: 0.9961 - val_loss: 0.6583 - val_accuracy: 0.9100
# Epoch 146/200
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.7191 - val_accuracy: 0.8900
# Epoch 147/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.6913 - val_accuracy: 0.9000
# Epoch 148/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.6518 - val_accuracy: 0.9000
# Epoch 149/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.6071 - val_accuracy: 0.9100
# Epoch 150/200
# 4/4 [==============================] - 0s 128ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5674 - val_accuracy: 0.9100
# Epoch 151/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5855 - val_accuracy: 0.9100
# Epoch 152/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6247 - val_accuracy: 0.9100
# Epoch 153/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6603 - val_accuracy: 0.9100
# Epoch 154/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.6754 - val_accuracy: 0.9100
# Epoch 155/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6921 - val_accuracy: 0.9100
# Epoch 156/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7081 - val_accuracy: 0.9100
# Epoch 157/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.7177 - val_accuracy: 0.9100
# Epoch 158/200
# 4/4 [==============================] - 1s 133ms/step - loss: 3.1674e-04 - accuracy: 1.0000 - val_loss: 0.7260 - val_accuracy: 0.9100
# Epoch 159/200
# 4/4 [==============================] - 1s 137ms/step - loss: 3.5669e-04 - accuracy: 1.0000 - val_loss: 0.7322 - val_accuracy: 0.9100
# Epoch 160/200
# 4/4 [==============================] - 1s 135ms/step - loss: 4.9400e-04 - accuracy: 1.0000 - val_loss: 0.7389 - val_accuracy: 0.9100
# Epoch 161/200
# 4/4 [==============================] - 1s 130ms/step - loss: 3.4408e-04 - accuracy: 1.0000 - val_loss: 0.7439 - val_accuracy: 0.9100
# Epoch 162/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.7487 - val_accuracy: 0.9100
# Epoch 163/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0061 - accuracy: 0.9961 - val_loss: 0.7476 - val_accuracy: 0.9100
# Epoch 164/200
# 4/4 [==============================] - 1s 143ms/step - loss: 1.4666e-04 - accuracy: 1.0000 - val_loss: 0.7470 - val_accuracy: 0.9100
# Epoch 165/200
# 4/4 [==============================] - 1s 155ms/step - loss: 2.0645e-04 - accuracy: 1.0000 - val_loss: 0.7483 - val_accuracy: 0.9100
# Epoch 166/200
# 4/4 [==============================] - 1s 132ms/step - loss: 5.1157e-04 - accuracy: 1.0000 - val_loss: 0.7526 - val_accuracy: 0.9100
# Epoch 167/200
# 4/4 [==============================] - 1s 133ms/step - loss: 2.5159e-04 - accuracy: 1.0000 - val_loss: 0.7587 - val_accuracy: 0.9100
# Epoch 168/200
# 4/4 [==============================] - 1s 138ms/step - loss: 4.0798e-04 - accuracy: 1.0000 - val_loss: 0.7653 - val_accuracy: 0.9100
# Epoch 169/200
# 4/4 [==============================] - 1s 134ms/step - loss: 7.1840e-04 - accuracy: 1.0000 - val_loss: 0.7714 - val_accuracy: 0.9100
# Epoch 170/200
# 4/4 [==============================] - 1s 134ms/step - loss: 5.8342e-04 - accuracy: 1.0000 - val_loss: 0.7854 - val_accuracy: 0.9100
# Epoch 171/200
# 4/4 [==============================] - 1s 133ms/step - loss: 2.4144e-04 - accuracy: 1.0000 - val_loss: 0.7990 - val_accuracy: 0.9100
# Epoch 172/200
# 4/4 [==============================] - 1s 136ms/step - loss: 2.2323e-04 - accuracy: 1.0000 - val_loss: 0.8086 - val_accuracy: 0.9100
# Epoch 173/200
# 4/4 [==============================] - 1s 139ms/step - loss: 1.5124e-04 - accuracy: 1.0000 - val_loss: 0.8153 - val_accuracy: 0.9100
# Epoch 174/200
# 4/4 [==============================] - 1s 132ms/step - loss: 8.6467e-04 - accuracy: 1.0000 - val_loss: 0.8273 - val_accuracy: 0.9100
# Epoch 175/200
# 4/4 [==============================] - 1s 137ms/step - loss: 2.1041e-04 - accuracy: 1.0000 - val_loss: 0.8421 - val_accuracy: 0.9100
# Epoch 176/200
# 4/4 [==============================] - 1s 134ms/step - loss: 1.5229e-04 - accuracy: 1.0000 - val_loss: 0.8529 - val_accuracy: 0.9100
# Epoch 177/200
# 4/4 [==============================] - 1s 134ms/step - loss: 4.7537e-04 - accuracy: 1.0000 - val_loss: 0.8609 - val_accuracy: 0.9100
# Epoch 178/200
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0059 - accuracy: 0.9961 - val_loss: 0.8837 - val_accuracy: 0.9100
# Epoch 179/200
# 4/4 [==============================] - 1s 146ms/step - loss: 6.7001e-04 - accuracy: 1.0000 - val_loss: 0.9036 - val_accuracy: 0.9100
# Epoch 180/200
# 4/4 [==============================] - 1s 129ms/step - loss: 9.6520e-04 - accuracy: 1.0000 - val_loss: 0.9187 - val_accuracy: 0.9100
# Epoch 181/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.9228 - val_accuracy: 0.9100
# Epoch 182/200
# 4/4 [==============================] - 1s 137ms/step - loss: 2.6411e-04 - accuracy: 1.0000 - val_loss: 0.9250 - val_accuracy: 0.9100
# Epoch 183/200
# 4/4 [==============================] - 1s 138ms/step - loss: 4.9311e-04 - accuracy: 1.0000 - val_loss: 0.9260 - val_accuracy: 0.9100
# Epoch 184/200
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.9241 - val_accuracy: 0.9100
# Epoch 185/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.8860 - val_accuracy: 0.9100
# Epoch 186/200
# 4/4 [==============================] - 1s 129ms/step - loss: 1.6085e-04 - accuracy: 1.0000 - val_loss: 0.8588 - val_accuracy: 0.9100
# Epoch 187/200
# 4/4 [==============================] - 1s 138ms/step - loss: 3.2852e-04 - accuracy: 1.0000 - val_loss: 0.8400 - val_accuracy: 0.9100
# Epoch 188/200
# 4/4 [==============================] - 1s 137ms/step - loss: 3.6786e-04 - accuracy: 1.0000 - val_loss: 0.8303 - val_accuracy: 0.9100
# Epoch 189/200
# 4/4 [==============================] - 1s 137ms/step - loss: 7.4971e-05 - accuracy: 1.0000 - val_loss: 0.8247 - val_accuracy: 0.9100
# Epoch 190/200
# 4/4 [==============================] - 1s 132ms/step - loss: 3.4189e-04 - accuracy: 1.0000 - val_loss: 0.8246 - val_accuracy: 0.9100
# Epoch 191/200
# 4/4 [==============================] - 1s 144ms/step - loss: 7.0478e-04 - accuracy: 1.0000 - val_loss: 0.8301 - val_accuracy: 0.9100
# Epoch 192/200
# 4/4 [==============================] - 1s 132ms/step - loss: 7.9579e-04 - accuracy: 1.0000 - val_loss: 0.8409 - val_accuracy: 0.9100
# Epoch 193/200
# 4/4 [==============================] - 1s 137ms/step - loss: 1.3812e-04 - accuracy: 1.0000 - val_loss: 0.8477 - val_accuracy: 0.9100
# Epoch 194/200
# 4/4 [==============================] - 1s 137ms/step - loss: 1.2015e-04 - accuracy: 1.0000 - val_loss: 0.8540 - val_accuracy: 0.9100
# Epoch 195/200
# 4/4 [==============================] - 1s 139ms/step - loss: 4.8015e-04 - accuracy: 1.0000 - val_loss: 0.8598 - val_accuracy: 0.9100
# Epoch 196/200
# 4/4 [==============================] - 1s 137ms/step - loss: 4.7297e-04 - accuracy: 1.0000 - val_loss: 0.8621 - val_accuracy: 0.9100
# Epoch 197/200
# 4/4 [==============================] - 1s 135ms/step - loss: 2.2120e-04 - accuracy: 1.0000 - val_loss: 0.8646 - val_accuracy: 0.9100
# Epoch 198/200
# 4/4 [==============================] - 1s 134ms/step - loss: 3.2283e-04 - accuracy: 1.0000 - val_loss: 0.8613 - val_accuracy: 0.9100
# Epoch 199/200
# 4/4 [==============================] - 1s 138ms/step - loss: 8.3336e-05 - accuracy: 1.0000 - val_loss: 0.8545 - val_accuracy: 0.9100
# Epoch 200/200
# 4/4 [==============================] - 1s 150ms/step - loss: 6.1892e-04 - accuracy: 1.0000 - val_loss: 0.9018 - val_accuracy: 0.9100
